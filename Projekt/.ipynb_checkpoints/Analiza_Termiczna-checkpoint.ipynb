# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import rc
# %matplotlib inline

# %%
rc('font', family='Comic Sans MS')

# %%
dane = pd.read_csv('analiza_termiczna_1.txt','\t')

# %%
dane.plot('t /s','T /C')
dane.plot('T /C','HF /mw')

# %%
#Przejście szkliste
dane_szkliste = dane[dane['T /C'] <= 300] # początkowa prosta przed przejściem szklistym
szkliste = np.polyfit(dane_szkliste['T /C'],dane_szkliste['HF /mw'],0)
krysztal_min = dane[dane['HF /mw'] == min(dane['HF /mw'][dane['T /C']<400])]
krysztal_min = krysztal_min[krysztal_min['T /C'] == min(krysztal_min['T /C'])] #Minimum między szklistym a krystalizacją
szkliste_srednia = (szkliste+krysztal_min['HF /mw'])/2 
dane_szkliste_temp = dane[dane['T /C']<float(krysztal_min['T /C'])]
szkliste_temp =  dane_szkliste_temp.loc[(dane_szkliste_temp['HF /mw']-float(szkliste_srednia)).abs().argsort()[:1]] #Temperatura przejscia szklistego

#Powstawanie kryształu
maksimum_krystalizacji = dane[dane['HF /mw'] == max(dane['HF /mw'])] # Temperatura krystalizacji
dane_krystalizacja = dane[int(krysztal_min.index.values):int(maksimum_krystalizacji.index.values)]
krystalizacja = np.polyfit(dane_krystalizacja['T /C'],dane_krystalizacja['HF /mw'],1)
krysztal_poczatek = (float(krysztal_min['T /C'])-krystalizacja[1])/krystalizacja[0]

granica_przejscieszkliste_krystalizacja = np.roots(krystalizacja - [0, float(krysztal_min['HF /mw'])])

#Topnienie
dane_topnienie = dane[dane['HF /mw'] < float(krysztal_min['HF /mw'])]
dane_krysztal_end = dane[(float(maksimum_krystalizacji['T /C']) <dane['T /C']) * (dane['HF /mw'] > float(krysztal_min['HF /mw']) )]
krystalizacja_end = np.polyfit(dane_krysztal_end['T /C'],dane_krysztal_end['HF /mw'],1)
topnienie = np.polyfit(dane_topnienie['T /C'],dane_topnienie['HF /mw'],1)

temperatura_topnienia = np.roots(krystalizacja_end-topnienie)

temperatura_topnienia
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py:183: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   unsupported[op_str]))
# array([ 442.56675598])

# %%
plt.plot(dane['T /C'],dane['HF /mw'],'k')
plt.grid()
plt.title('Analiza termiczna')
plt.xlabel(r'T[$^\circ$C]')
plt.ylabel('HF[mW]')
plt.annotate('Przejście szkliste',(320,0),xytext=(50, -35),arrowprops=dict(facecolor='black', shrink=0.05))
plt.hlines(np.polyval(szkliste,[50,200]),50,300,'m')
plt.hlines(krysztal_min['HF /mw'],250,375,'b')
plt.plot(dane_krystalizacja['T /C'],np.polyval(krystalizacja,dane_krystalizacja['T /C']),'#FFA500')
plt.plot(szkliste_temp['T /C'],szkliste_temp['HF /mw'],'ro')
plt.plot(granica_przejscieszkliste_krystalizacja,krysztal_min['HF /mw'],'ro')
plt.annotate('Początek krystalizacji',(granica_przejscieszkliste_krystalizacja,krysztal_min['HF /mw']-5),
             xytext=(granica_przejscieszkliste_krystalizacja,krysztal_min['HF /mw']-35),arrowprops=dict(facecolor='black', shrink=0.05))
plt.plot(maksimum_krystalizacji['T /C'],maksimum_krystalizacji['HF /mw'],'or')
plt.annotate('Krystalizacja',(maksimum_krystalizacji['T /C'],maksimum_krystalizacji['HF /mw']),xytext=(maksimum_krystalizacji['T /C']-200,maksimum_krystalizacji['HF /mw']-5),arrowprops=dict(facecolor='black', shrink=0.05))
plt.plot(dane_krysztal_end['T /C'],np.polyval(krystalizacja_end,dane_krysztal_end['T /C']),'g')
plt.plot(dane_topnienie['T /C'],np.polyval(topnienie,dane_topnienie['T /C']),'c')
plt.plot(temperatura_topnienia,np.polyval(topnienie,temperatura_topnienia),'ro')
plt.annotate('Topnienie',(temperatura_topnienia,np.polyval(topnienie,temperatura_topnienia)),xytext=(temperatura_topnienia+50,np.polyval(topnienie,temperatura_topnienia)+20),arrowprops=dict(facecolor='black', shrink=0.05))
plt.savefig('Analiza_termiczna.png',dpi = 400)

# %%
plt.plot?

# %%
# Out:
# (array([   1.50760036, -545.6846818 ]), array([   1.50760036, -899.3646818 ]))

# %%
# Out:
# pandas.core.series.Series
