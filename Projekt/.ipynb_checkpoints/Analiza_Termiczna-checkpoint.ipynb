# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
dane = pd.read_csv('analiza_termiczna_1.txt','\t')

# %%
dane.plot('t /s','T /C')
dane.plot('T /C','HF /mw')

# %%
plt.plot(dane['T /C'],dane['HF /mw'])
